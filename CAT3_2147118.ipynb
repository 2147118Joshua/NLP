# %% [markdown]
# <a href="https://colab.research.google.com/github/2147118Joshua/NLP/blob/main/CAT3_2147118.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---“Early in 1969, Fiat took a 50% stake in Ferrari. An immediate result was an
# increase in available investment funds, and work started at once on a factory
# extension intended to transfer production from Fiat&#39;s Turin plant of the Ferrari
# engined Fiat Dino. New model investment further up in the Ferrari range also
# received a boost”

# %% [markdown]
# #Generate Sentence &amp; Word tokens. (3 MARKS)

# %%
#tokenizing
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
import nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize


text= "Early in 1969, Fiat took a 50% stake in Ferrari. An immediate result was an increase in available investment funds, and work started at once on a factory extension intended to transfer production from Fiat's Turin plant of the Ferrari engined Fiat Dino. New model investment further up in the Ferrari range also received a boost"

print("sentence tokenizer")
print(sent_tokenize(text));
print("\n\n word tokenizer")
print(word_tokenize(text));
# Out:
# sentence tokenizer
# ['Early in 1969, Fiat took a 50% stake in Ferrari.', "An immediate result was an increase in available investment funds, and work started at once on a factory extension intended to transfer production from Fiat's Turin plant of the Ferrari engined Fiat Dino.", 'New model investment further up in the Ferrari range also received a boost']
#
#
#  word tokenizer
# ['Early', 'in', '1969', ',', 'Fiat', 'took', 'a', '50', '%', 'stake', 'in', 'Ferrari', '.', 'An', 'immediate', 'result', 'was', 'an', 'increase', 'in', 'available', 'investment', 'funds', ',', 'and', 'work', 'started', 'at', 'once', 'on', 'a', 'factory', 'extension', 'intended', 'to', 'transfer', 'production', 'from', 'Fiat', "'s", 'Turin', 'plant', 'of', 'the', 'Ferrari', 'engined', 'Fiat', 'Dino', '.', 'New', 'model', 'investment', 'further', 'up', 'in', 'the', 'Ferrari', 'range', 'also', 'received', 'a', 'boost']
# [nltk_data] Downloading package punkt to /root/nltk_data...
# ...

# %% [markdown]
# #Remove the Stop words. (3 MARKS)

# %%
import nltk
import pandas as pd
import seaborn as sns

nltk.download('stopwords')
nltk.download('punkt')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize


final_words = nltk.word_tokenize(text)
new_words= [word for word in final_words if word.isalnum()]

print("final words>>>>>>>>>", new_words)

#  convert a list
# to string using list comprehension

# using list comprehension
listToStr = ' '.join([str(elem) for elem in new_words])

print("string conversion>>>>>",listToStr)

#“the”, “is” and “and”, would easily qualify as stop words

stop_words = set(stopwords.words('english'))

#Creating tokenzier with NLTK

word_tokens = word_tokenize(listToStr)

#displaying the sentence after removing stop words

filtered_sentence = [w for w in word_tokens if not w in stop_words]
filtered_sentence = []

for w in word_tokens:
    if w not in stop_words:
        filtered_sentence.append(w)

print(filtered_sentence)
# Out:
# final words>>>>>>>>> ['Early', 'in', '1969', 'Fiat', 'took', 'a', '50', 'stake', 'in', 'Ferrari', 'An', 'immediate', 'result', 'was', 'an', 'increase', 'in', 'available', 'investment', 'funds', 'and', 'work', 'started', 'at', 'once', 'on', 'a', 'factory', 'extension', 'intended', 'to', 'transfer', 'production', 'from', 'Fiat', 'Turin', 'plant', 'of', 'the', 'Ferrari', 'engined', 'Fiat', 'Dino', 'New', 'model', 'investment', 'further', 'up', 'in', 'the', 'Ferrari', 'range', 'also', 'received', 'a', 'boost']
# string conversion>>>>> Early in 1969 Fiat took a 50 stake in Ferrari An immediate result was an increase in available investment funds and work started at once on a factory extension intended to transfer production from Fiat Turin plant of the Ferrari engined Fiat Dino New model investment further up in the Ferrari range also received a boost
# ...

# %%
import nltk 
nltk.download('wordnet') 
nltk.download('omw-1.4')
nltk.download('punkt')
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# #Implement Lemmatization and Stemming of any 5 cleaned tokens.

# %%
lemmatizer = WordNetLemmatizer()
print("investment :")
print(lemmatizer.lemmatize(" investment"))
print("\nextension :")
print(lemmatizer.lemmatize(" extension"))
print("\nproduction :")
print(lemmatizer.lemmatize("production"))
print("\nengined :")
print(lemmatizer.lemmatize("engined"))
print("\nincrease :")
print(lemmatizer.lemmatize("increase"))
# Out:
# investment :
#  investment
#
# extension :
#  extension
#
# production :
# production
#
# engined :
# engined
#
# increase :
# increase

# %%
from nltk.stem import PorterStemmer
from nltk.stem import LancasterStemmer

# %%
#create an object of class PorterStemmer
porter = PorterStemmer()
lancaster=LancasterStemmer()
#proide a word to be stemmed
print("Porter Stemmer")
print(porter.stem("investment"))
print(porter.stem("extension"))
print(porter.stem("production"))
print(porter.stem("engined"))
print(porter.stem("increase"))
print("Lancaster Stemmer")
print(lancaster.stem("investment"))
print(lancaster.stem("extension"))
print(lancaster.stem("production"))
print(lancaster.stem("engined"))
print(lancaster.stem("increase"))
# Out:
# Porter Stemmer
# invest
# extens
# product
# engin
# increas
# Lancaster Stemmer
# invest
# extend
# produc
# engin
# increas

# %% [markdown]
# ##Program 2

# %% [markdown]
# Project Gutenberg e-archive using
# appropriate file identifiers

# %%
import nltk
nltk.download('gutenberg')
nltk.corpus.gutenberg.fileids()
# Out:
# [nltk_data] Downloading package gutenberg to /root/nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
emma = nltk.corpus.gutenberg.words('austen-emma.txt')
len(emma)
# Out:
# 192427

# %%
print(emma)
# Out:
# ['[', 'Emma', 'by', 'Jane', 'Austen', '1816', ']', ...]

# %%
new_words= [word for word in emma if word.isalnum()]


listToStr = ' '.join([str(elem) for elem in new_words])

print("string conversion>>>>>",listToStr)

#“the”, “is” and “and”, would easily qualify as stop words (removing)

stop_words = set(stopwords.words('english'))

#Creating tokenzier with NLTK

word_tokens = word_tokenize(listToStr)

#displaying the sentence after removing stop words

filtered_sentence = [w for w in word_tokens if not w in stop_words]
filtered_sentence = []

for w in word_tokens:
    if w not in stop_words:
        filtered_sentence.append(w)

print(filtered_sentence) 

#count of words after filtering the sentences

wordfreq = []
for w in filtered_sentence:
    wordfreq.append(filtered_sentence.count(w))

FreqDist(filtered_sentence)
filtered_sentence

for i in filtered_sentence:
 print(i, '-----', wordfreq[filtered_sentence.index(i)])

all_fdist = pd.Series(wordfreq)

fig, ax = plt.subplots(figsize=(30,10))
all_plot = sns.barplot(x=filtered_sentence, y=all_fdist.values, ax=ax)
plt.xticks(rotation=50);
# Out:
# Streaming output truncated to the last 5000 lines.
# one ----- 413
# ever ----- 189
# finished ----- 12
# might ----- 322
# decide ----- 5
# together ----- 81
# best ----- 85
# size ----- 12
# Harriet ----- 506
# Her ----- 88
# many ----- 133
# beginnings ----- 1
# displayed ----- 2
# Miniatures ----- 1
# half ----- 116
# lengths ----- 2
# whole ----- 76
# lengths ----- 2
# pencil ----- 5
# crayon ----- 1
# water ----- 8
# colours ----- 3
# tried ----- 26
# turn ----- 28
# She ----- 562
# always ----- 235
# wanted ----- 75
# every ----- 398
# thing ----- 398
# made ----- 199
# progress ----- 9
# drawing ----- 30
# music ----- 24
# many ----- 133
# might ----- 322
# done ----- 142
# little ----- 354
# labour ----- 4
# would ----- 815
# ever ----- 189
# submit ----- 3
# She ----- 562
# played ----- 8
# sang ----- 3
# drew ----- 6
# almost ----- 87
# every ----- 398
# style ----- 27
# steadiness ----- 4
# always ----- 235
# wanting ----- 33
# nothing ----- 237
# approached ----- 5
# ...

# %% [markdown]
# ##Program3

# %%
import nltk 
nltk.download('wordnet') 
nltk.download('omw-1.4')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.stem import WordNetLemmatizer

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
pip install gensim
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# Python program to generate word vectors using Word2Vec

# importing all necessary modules
from nltk.tokenize import sent_tokenize, word_tokenize
import warnings

warnings.filterwarnings(action = 'ignore')

import gensim
from gensim.models import Word2Vec

# Reads ‘alice.txt’ file
sample = open("Alice.txt")

s = sample.read()


# Replaces escape character with space
f = s.replace("\n", " ")

data = []

# iterate through each sentence in the file
for i in sent_tokenize(f):
	temp = []
	
	# tokenize the sentence into words
	for j in word_tokenize(i):
		temp.append(j.lower())

	data.append(temp)

# Create CBOW model
model1 = gensim.models.Word2Vec(data, min_count = 1,vector_size = 100, window = 5)

# Print results
print("Cosine similarity between 'alice' " +
			"and 'wonderland' - CBOW : ",
	model1.wv.similarity('alice', 'wonderland'))
	
print("Cosine similarity between 'alice' " +
				"and 'machines' - CBOW : ",
	model1.wv.similarity('alice', 'machines'))

# Create Skip Gram model
model2 = gensim.models.Word2Vec(data, min_count = 1, vector_size = 100,
											window = 5, sg = 1)

# Print results
print("Cosine similarity between 'alice' " +
		"and 'wonderland' - Skip Gram : ",
	model2.wv.similarity('alice', 'wonderland'))
	
print("Cosine similarity between 'alice' " +
			"and 'machines' - Skip Gram : ",
	model2.wv.similarity('alice', 'machines'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-d6d81acd95dd> in <module>
#      32
#      33 # Create CBOW model
# ---> 34 model1 = gensim.models.Word2Vec(data, min_count = 1,vector_size = 100, window = 5)
#      35
#      36 # Print results
#
# TypeError: __init__() got an unexpected keyword argument 'vector_size'

# %%
text1=" Suddenly she came upon a little three-legged table, all made of solid glass; there was nothing on it except a tiny golden key, and Alice's first thought was that it might belong to one of the doors of the hall; but, alas! either the locks were too large, or the key was too small, but at any rate it would not open any of them "

# %%
print("original Text :")
print(text1)
word_list = nltk.word_tokenize(text1)
print("\ntokinzed sentence:")
print(word_list)
# Out:
# original Text :
#  Suddenly she came upon a little three-legged table, all made of solid glass; there was nothing on it except a tiny golden key, and Alice's first thought was that it might belong to one of the doors of the hall; but, alas! either the locks were too large, or the key was too small, but at any rate it would not open any of them
#
# tokinzed sentence:
# ['Suddenly', 'she', 'came', 'upon', 'a', 'little', 'three-legged', 'table', ',', 'all', 'made', 'of', 'solid', 'glass', ';', 'there', 'was', 'nothing', 'on', 'it', 'except', 'a', 'tiny', 'golden', 'key', ',', 'and', 'Alice', "'s", 'first', 'thought', 'was', 'that', 'it', 'might', 'belong', 'to', 'one', 'of', 'the', 'doors', 'of', 'the', 'hall', ';', 'but', ',', 'alas', '!', 'either', 'the', 'locks', 'were', 'too', 'large', ',', 'or', 'the', 'key', 'was', 'too', 'small', ',', 'but', 'at', 'any', 'rate', 'it', 'would', 'not', 'open', 'any', 'of', 'them']

# %%
print(nltk.pos_tag(nltk.word_tokenize(text1)))
# Out:
# [('Suddenly', 'RB'), ('she', 'PRP'), ('came', 'VBD'), ('upon', 'IN'), ('a', 'DT'), ('little', 'JJ'), ('three-legged', 'JJ'), ('table', 'NN'), (',', ','), ('all', 'DT'), ('made', 'VBN'), ('of', 'IN'), ('solid', 'JJ'), ('glass', 'NN'), (';', ':'), ('there', 'EX'), ('was', 'VBD'), ('nothing', 'NN'), ('on', 'IN'), ('it', 'PRP'), ('except', 'IN'), ('a', 'DT'), ('tiny', 'JJ'), ('golden', 'JJ'), ('key', 'NN'), (',', ','), ('and', 'CC'), ('Alice', 'NNP'), ("'s", 'POS'), ('first', 'JJ'), ('thought', 'NN'), ('was', 'VBD'), ('that', 'IN'), ('it', 'PRP'), ('might', 'MD'), ('belong', 'VB'), ('to', 'TO'), ('one', 'CD'), ('of', 'IN'), ('the', 'DT'), ('doors', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('hall', 'NN'), (';', ':'), ('but', 'CC'), (',', ','), ('alas', 'UH'), ('!', '.'), ('either', 'CC'), ('the', 'DT'), ('locks', 'NNS'), ('were', 'VBD'), ('too', 'RB'), ('large', 'JJ'), (',', ','), ('or', 'CC'), ('the', 'DT'), ('key', 'NN'), ('was', 'VBD'), ('too', 'RB'), ('small', 'JJ'), (',', ','), ('but', '
# ...

# %%
import spacy
from spacy import displacy
sp=spacy.load('en_core_web_sm')
text=sp("Suddenly she came upon a little three-legged table, all made of solid glass; there was nothing on it except a tiny golden key.")
displacy.render(text,style='dep',options={'distance':85},jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="d3437c1a54bf42158b93cb29c23fb906-0" class="displacy" width="2090" height="392.0" direction="ltr" style="max-width: none; height: 392.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="302.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Suddenly</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="302.0">
#     <tspan class="displacy-word" fill="currentColor" x="135">she</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="135">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="302.0">
# ...
